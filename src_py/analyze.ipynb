# %%
import pandas as pd

# %%
df_ans = pd.read_csv("./csv/Answers_rows.csv").set_index("id")
df_meta = pd.read_csv("./csv/SampleMetaData_rows.csv")
df_meta = df_meta.rename(columns={"id": "sample_meta_data_id"})
df_ans = df_ans.merge(df_meta, on=["sample_meta_data_id"], how="inner")
df_ans
# Out:
#     respondent_id  sample_meta_data_id  naturalness_id  intelligibility_id  \
# 0               1                  248               1                   1
# 1               1                  243               1                   1
# 2               1                  246               1                   1
# 3               1                  250               1                   1
# 4               1                  241               1                   1
# 5               1                  245               1                   1
# 6               1                  247               1                   1
# 7               1                  244               1                   1
# 8               1                  249               1                   1
# 9               1                  242               1                   1
# 10              1                   10               1                   1
# ...
